# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("tesla-stocks-data.csv")

# %%
df.head(3)
# Out:
#          Date  Close/Last    Volume    Open       High          Low
# 0  07/29/2020    $1499.11   9426893   $1501   $1534.81        $1487
# 1  07/28/2020    $1476.49  15808700   $1504    $1564.7     $1474.42
# 2  07/27/2020     $1539.6  16048670   $1435   $1547.94   $1413.0003

# %%
df.columns
# Out:
# Index(['Date', ' Close/Last', ' Volume', ' Open', ' High', ' Low'], dtype='object')

# %%
df.dtypes
# Out:
# Date           object
#  Close/Last    object
#  Volume         int64
#  Open          object
#  High          object
#  Low           object
# dtype: object

# %%
df.Date = pd.to_datetime(df.Date)
df.head(3)
# Out:
#         Date  Close/Last    Volume    Open       High          Low
# 0 2020-07-29    $1499.11   9426893   $1501   $1534.81        $1487
# 1 2020-07-28    $1476.49  15808700   $1504    $1564.7     $1474.42
# 2 2020-07-27     $1539.6  16048670   $1435   $1547.94   $1413.0003

# %%
df
# Out:
#          Date  Close/Last    Volume Open(in Dollar) High(in Dollar)  \
# 0  2020-07-29    $1499.11   9426893           $1501        $1534.81
# 1  2020-07-28    $1476.49  15808700           $1504         $1564.7
# 2  2020-07-27     $1539.6  16048670           $1435        $1547.94
# 3  2020-07-24       $1417  19396620        $1416.01           $1465
# 4  2020-07-23    $1513.07  24328500        $1678.95           $1689
# 5  2020-07-22    $1592.33  14161080           $1599        $1626.42
# 6  2020-07-21    $1568.36  16157280        $1639.93           $1675
# 7  2020-07-20       $1643  17121370        $1519.01           $1650
# 8  2020-07-17    $1500.84   9329972        $1513.45        $1537.51
# 9  2020-07-16    $1500.64  14300790        $1477.16        $1531.71
# 10 2020-07-15    $1546.01  16367830           $1543           $1550
# 11 2020-07-14     $1516.8  23418140           $1556           $1590
# 12 2020-07-13    $1497.06  38985360           $1659        $1794.99
# ...
